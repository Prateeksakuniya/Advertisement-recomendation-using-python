# %%
import pandas as pd
A = pd.read_csv("C:\\Users\\user\\Desktop\\advertising.csv")
print(A)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
A.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
A.TV.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as pt
pt.scatter(A['TV'],A['Sales'])

# %%
print(A['TV'].corr(A['Radio']))
# Out:
# 0.054808664465830034

# %%
print(A['TV'].corr(A['Newspaper']))
# Out:
# 0.056647874965056945

# %%
print(A['TV'].corr(A['Sales']))
# Out:
# 0.9012079133023306

# %%
print(A['Sales'].corr(A['Radio']))
# Out:
# 0.34963109700766937

# %%
print(A['Sales'].corr(A['Newspaper']))
# Out:
# 0.15796002615492624

# %%
pt.scatter(A['Newspaper'],A['Sales'])

# %%
pt.scatter(A['Radio'],A['Sales'])

# %%
pt.figure(figsize=(15,6))
# fig= plt.figure(figsize=(6, 3))  # 6 inches wide, 3 inches tall

# Create the first subplot (1 row, 3 columns, first plot)
ax1 = pt.subplot(1, 3,1)#(rows,columns,placing)#return axis and figure
ax1.scatter(A['TV'], A['Sales'], label="TV vs Sales")
pt.xlabel("TV")
pt.ylabel("Sales")
pt.legend()
# Create the second subplot (1 row, 2 columns, second plot)
ax2 = pt.subplot(1, 3, 2)
ax2.scatter(A['Newspaper'], A['Sales'], label="Newspaper vs Sales")
pt.xlabel("Newspaper")
pt.ylabel("Sales")
pt.legend()
ax3=pt.subplot(1,3,3)
ax3.scatter(A['Radio'], A['Sales'], label="Radio vs Sales")
pt.xlabel("Radio")
pt.ylabel("Sales")
# Display the plot
pt.legend()

pt.show()

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit([[0, 0], [0, 0], [1, 1]], [0, .1, 1])
reg.coef_
reg.intercept_
# Out:
# 0.1363636363636364

# %%
reg.fit(A[[["TV"]]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 reg.fit(A[[["TV"]]])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# ...

# %%
# import packages
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# head of the data
print(A.head())

X= A['TV']
y=A['Sales']

# using the train test split function
X_train, X_test,
y_train, y_test = train_test_split(X,y,random_state=104,test_size=0.25,shuffle=True)
print('X_train :TV ')
print(X_train.head())
print('')
print('X_test :TV ')
print(X_test.head())
print('')
print('y_train :Sales ')
print(y_train.head())
print('')
print('y_test :Sales ')
print(y_test.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 13
#      11 # using the train test split function
#      12 X_train, X_test,
# ---> 13 y_train, y_test = train_test_split(X,y,random_state=104,test_size=0.25,shuffle=True)
#      14 print('X_train :TV ')
#      15 print(X_train.head())
#
# ValueError: too many values to unpack (expected 2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import linear_model
reg = linear_model.LinearRegression()
# X=music_data.drop(columns=['genre'])
# Y=music_data['genre']

X=A[['TV']]
Y=A['Sales']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=42, test_size=0.2)
reg.fit(X_train,Y_train)
predictions=reg.predict(X_test)

# %%
predictions
# Out:
# array([16.06747317, 17.84847567, 23.25806271,  7.65625887, 19.23000098,
#        11.17387752, 19.03581067,  9.78125562, 19.34651516, 16.72217191,
#         8.75482116, 10.12524988, 20.01785878,  7.30671633, 14.74697911,
#        16.45030549,  7.41213392, 17.97053815, 11.18497411, 20.17875932,
#        19.74044406, 10.76885203,  9.1154603 , 20.92777906, 10.83543156,
#         9.97544593, 18.85271696, 14.73588252, 11.84522114,  7.47316516,
#        18.09260063, 10.84652815, 18.04266598,  7.94477018, 22.58117079,
#        20.22314567,  9.68693462, 22.19279018, 13.50970946,  8.53288939])

# %%
reg.score(X_test,Y_test)
# Out:
# 0.802561303423698

# %%
reg.score(X_train,Y_train)
# Out:
# 0.8134866044709264

# %%
X_test
# Out:
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4
# 124  229.5
# 16    67.8
# 148   38.0
# 93   250.9
# 65    69.0
# 60    53.5
# 84   213.5
# 67   139.3
# 125   87.2
# 132    8.4
# 9    199.8
# 18    69.2
# 55   198.9
# 75    16.9
# 150  280.7
# 104  238.2
# 135   48.3
# 137  273.7
# 164  117.2
# 76    27.5

# %%
Y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    16.5
# 45     16.1
# 66     11.0
# 182     8.7
# 165    16.9
# 78      5.3
# 186    10.3
# 177    16.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65     11.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      15.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
pt.scatter([X_test],[Y_test])

# %%
pt.scatter([X_train],[Y_train])
